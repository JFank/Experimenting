# %%
a = linspace(0,10,num=1000)

# %%
b = sin(a)

# %%
c = linspace(0,10,num=1000)

# %%
d = cos(c)

# %%
plot(a,b); plot(c,d)

# %%
a = linspace(-10,10,num=1000)

# %%
b = (1/(cosh(a)))*(1/(cosh(a)))

# %%
plot(a,b)
